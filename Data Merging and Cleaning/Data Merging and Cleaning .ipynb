# %%
import pandas as pd 
import numpy as np
import glob

# %%
# Obtaine all necessary files from one folder: R_files
path=glob.glob('/Users/dasha/Documents/Capstone_2_files/Original_files2/*.xlsx')

# %%
#read the files (in excel format) and append the dataframes to a list 
df_list=[]
for file in path: 
    file_name=pd.read_excel(file)
    df_list.append(file_name)

# %%
# Generate a fuction for elimination and engineering of features 

irrelevant_columns=['Standard Error','Lower CI Bound','Upper CI Bound','Element Name','Scale Name','O*NET-SOC Code','N','Element ID','Scale ID','Recommend Suppress','Date','Domain Source','Not Relevant','Category']

def dropper(df): 
    # for files with a category column 
    if 'Category' in df.columns: 
        #some columns are NaN, replace with blanks for computation downstream
        df['Category'].replace(np.nan,'',inplace=True) 
        df['Category']=df['Category'].astype(str)
        df['Element_Name']=df['Element Name']+str('_Context_')+df['Category']
    else: 
        df['Element_Name']=df['Element Name']+str('_')+df['Scale Name']
    # drop unnecessary columns 
    for column in df.columns: 
        if column in irrelevant_columns: 
            df.drop(columns=column,inplace=True)

# %%
# execute the dropper function on all the loaded files 
[dropper(df_list[idx]) for idx,df in enumerate(df_list)]
# Out:
# [None, None, None, None, None, None, None]

# %%
# Concatenate all the files together into a single dataframe 
df=pd.concat(df_list,axis=0,ignore_index=True,sort=True)
df=df.iloc[:,[2,1,0]] # re-order the columns 
df=df[~df['Element_Name'].str.contains('_Level')]
df.head()
# Out:
#               Title                      Element_Name  Data Value
# 0  Chief Executives     Oral Comprehension_Importance        4.50
# 2  Chief Executives  Written Comprehension_Importance        4.25
# 4  Chief Executives        Oral Expression_Importance        4.38
# 6  Chief Executives     Written Expression_Importance        4.12
# 8  Chief Executives       Fluency of Ideas_Importance        3.88

# %%
# unstack the 'Element_Name' column into 'Data Value' and 'Standard Error'
df_expanded=df.pivot_table(index=['Title'],columns='Element_Name',values=['Data Value'])
df_expanded.head()
# Out:
#                                      Data Value                             \
# Element_Name      Achievement/Effort_Importance Active Learning_Importance
# Title
# Accountants                                3.63                       3.12
# Actors                                     4.73                       2.62
# Actuaries                                  4.44                       3.38
# Acupuncturists                             3.65                       3.12
# Acute Care Nurses                          4.25                       3.75
#
#                                                \
# Element_Name      Active Listening_Importance
# Title
# Accountants                              3.88
# Actors                                   3.75
# Actuaries                                4.00
# Acupuncturists                           3.75
# Acute Care Nurses                        4.00
#
#                                                        \
# Element_Name      Adaptability/Flexibility_Importance
# Title
# Accountants                                      3.78
# Actors                                           4.78
# Actuaries                                        3.81
# Acupuncturists                                   3.81
# Acute Care Nurses                                4.71
#
#                                                             \
# Element_Name      Administration and Management_Importance
# Title
# Accountants                                           3.11
# Actors                                                2.56
# Actuaries                                             3.31
# Acupuncturists                                        2.67
# Acute Care Nurses                                     2.89
#
#                                                   \
# Element_Name      Analytical Thinking_Importance
# Title
# Accountants                                 4.21
# Actors                                      3.25
# Actuaries                                   4.81
# Acupuncturists                              3.95
# Acute Care Nurses                           4.11
#
#                                                             \
# Element_Name      Analyzing Data or Information_Importance
# Title
# Accountants                                           3.93
# Actors                                                1.78
# Actuaries                                             4.88
# Acupuncturists                                        3.06
# Acute Care Nurses                                     3.48
#
#                                                   \
# Element_Name      Arm-Hand Steadiness_Importance
# Title
# Accountants                                 1.38
# Actors                                      2.00
# Actuaries                                   1.12
# Acupuncturists                              3.12
# Acute Care Nurses                           1.75
#
#                                                    \
# Element_Name      Artistic_Occupational Interests
# Title
# Accountants                                  1.00
# Actors                                       6.67
# Actuaries                                    1.67
# Acupuncturists                               2.33
# Acute Care Nurses                            2.00
#
#                                                               \
# Element_Name      Assisting and Caring for Others_Importance
# Title
# Accountants                                             2.44
# Actors                                                  2.39
# Actuaries                                               1.69
# Acupuncturists                                          4.32
# Acute Care Nurses                                       4.78
#
#                                ...               \
# Element_Name                   ...
# Title                          ...
# Accountants                    ...
# Actors                         ...
# Actuaries                      ...
# Acupuncturists                 ...
# Acute Care Nurses              ...
#
#                                                          \
# Element_Name      Work With Work Group or Team_Context_
# Title
# Accountants                                        3.66
# Actors                                             5.00
# Actuaries                                          3.97
# Acupuncturists                                     3.56
# Acute Care Nurses                                  4.77
#
#                                                             \
# Element_Name      Work With Work Group or Team_Context_1.0
# Title
# Accountants                                           16.3
# Actors                                                 0.0
# Actuaries                                              0.0
# Acupuncturists                                        13.6
# Acute Care Nurses                                      0.0
#
#                                                             \
# Element_Name      Work With Work Group or Team_Context_2.0
# Title
# Accountants                                          17.37
# Actors                                                0.00
# Actuaries                                             6.45
# Acupuncturists                                        3.14
# Acute Care Nurses                                     0.00
#
#                                                             \
# Element_Name      Work With Work Group or Team_Context_3.0
# Title
# Accountants                                           6.01
# Actors                                                0.00
# Actuaries                                            19.35
# Acupuncturists                                       29.95
# Acute Care Nurses                                     3.85
#
#                                                             \
# Element_Name      Work With Work Group or Team_Context_4.0
# Title
# Accountants                                           4.52
# Actors                                                0.00
# Actuaries                                            45.16
# Acupuncturists                                       20.79
# Acute Care Nurses                                    15.38
#
#                                                             \
# Element_Name      Work With Work Group or Team_Context_5.0
# Title
# Accountants                                          55.81
# Actors                                              100.00
# Actuaries                                            29.03
# Acupuncturists                                       32.53
# Acute Care Nurses                                    80.77
#
#                                                                     \
# Element_Name      Wrist-Finger Speed_Importance Writing_Importance
# Title
# Accountants                                1.38               3.62
# Actors                                     1.12               2.88
# Actuaries                                  1.25               3.38
# Acupuncturists                             1.38               3.25
# Acute Care Nurses                          1.38               3.50
#
#                                                     \
# Element_Name      Written Comprehension_Importance
# Title
# Accountants                                   4.00
# Actors                                        3.88
# Actuaries                                     4.00
# Acupuncturists                                3.50
# Acute Care Nurses                             4.00
#
#
# Element_Name      Written Expression_Importance
# Title
# Accountants                                3.75
# Actors                                     2.88
# Actuaries                                  3.75
# Acupuncturists                             3.25
# Acute Care Nurses                          3.75
#
# [5 rows x 523 columns]

# %%
#How many professions contain missing values?
print(df_expanded[df_expanded.isnull().any(axis=1)].shape[0])
# Out:
# 8

# %%
#Why did some rows have missing standard dev.? Maybe there were insufficient 
# measuremnts to determine std? Will drop any rows containing NaNs 
df_expanded=df_expanded.dropna(how='any',axis=0)
assert df_expanded.notnull().all().all()

# %%
df_dv=df_expanded['Data Value']
df_dv.reset_index(inplace=True)
df_dv.set_index('Title',inplace=True)
df_dv.head()
# Out:
# Element_Name       Achievement/Effort_Importance  Active Learning_Importance  \
# Title
# Accountants                                 3.63                        3.12
# Actors                                      4.73                        2.62
# Actuaries                                   4.44                        3.38
# Acupuncturists                              3.65                        3.12
# Acute Care Nurses                           4.25                        3.75
#
# Element_Name       Active Listening_Importance  \
# Title
# Accountants                               3.88
# Actors                                    3.75
# Actuaries                                 4.00
# Acupuncturists                            3.75
# Acute Care Nurses                         4.00
#
# Element_Name       Adaptability/Flexibility_Importance  \
# Title
# Accountants                                       3.78
# Actors                                            4.78
# Actuaries                                         3.81
# Acupuncturists                                    3.81
# Acute Care Nurses                                 4.71
#
# Element_Name       Administration and Management_Importance  \
# Title
# Accountants                                            3.11
# Actors                                                 2.56
# Actuaries                                              3.31
# Acupuncturists                                         2.67
# Acute Care Nurses                                      2.89
#
# Element_Name       Analytical Thinking_Importance  \
# Title
# Accountants                                  4.21
# Actors                                       3.25
# Actuaries                                    4.81
# Acupuncturists                               3.95
# Acute Care Nurses                            4.11
#
# Element_Name       Analyzing Data or Information_Importance  \
# Title
# Accountants                                            3.93
# Actors                                                 1.78
# Actuaries                                              4.88
# Acupuncturists                                         3.06
# Acute Care Nurses                                      3.48
#
# Element_Name       Arm-Hand Steadiness_Importance  \
# Title
# Accountants                                  1.38
# Actors                                       2.00
# Actuaries                                    1.12
# Acupuncturists                               3.12
# Acute Care Nurses                            1.75
#
# Element_Name       Artistic_Occupational Interests  \
# Title
# Accountants                                   1.00
# Actors                                        6.67
# Actuaries                                     1.67
# Acupuncturists                                2.33
# Acute Care Nurses                             2.00
#
# Element_Name       Assisting and Caring for Others_Importance  \
# Title
# Accountants                                              2.44
# Actors                                                   2.39
# Actuaries                                                1.69
# Acupuncturists                                           4.32
# Acute Care Nurses                                        4.78
#
# Element_Name                   ...                \
# Title                          ...
# Accountants                    ...
# Actors                         ...
# Actuaries                      ...
# Acupuncturists                 ...
# Acute Care Nurses              ...
#
# Element_Name       Work With Work Group or Team_Context_  \
# Title
# Accountants                                         3.66
# Actors                                              5.00
# Actuaries                                           3.97
# Acupuncturists                                      3.56
# Acute Care Nurses                                   4.77
#
# Element_Name       Work With Work Group or Team_Context_1.0  \
# Title
# Accountants                                            16.3
# Actors                                                  0.0
# Actuaries                                               0.0
# Acupuncturists                                         13.6
# Acute Care Nurses                                       0.0
#
# Element_Name       Work With Work Group or Team_Context_2.0  \
# Title
# Accountants                                           17.37
# Actors                                                 0.00
# Actuaries                                              6.45
# Acupuncturists                                         3.14
# Acute Care Nurses                                      0.00
#
# Element_Name       Work With Work Group or Team_Context_3.0  \
# Title
# Accountants                                            6.01
# Actors                                                 0.00
# Actuaries                                             19.35
# Acupuncturists                                        29.95
# Acute Care Nurses                                      3.85
#
# Element_Name       Work With Work Group or Team_Context_4.0  \
# Title
# Accountants                                            4.52
# Actors                                                 0.00
# Actuaries                                             45.16
# Acupuncturists                                        20.79
# Acute Care Nurses                                     15.38
#
# Element_Name       Work With Work Group or Team_Context_5.0  \
# Title
# Accountants                                           55.81
# Actors                                               100.00
# Actuaries                                             29.03
# Acupuncturists                                        32.53
# Acute Care Nurses                                     80.77
#
# Element_Name       Wrist-Finger Speed_Importance  Writing_Importance  \
# Title
# Accountants                                 1.38                3.62
# Actors                                      1.12                2.88
# Actuaries                                   1.25                3.38
# Acupuncturists                              1.38                3.25
# Acute Care Nurses                           1.38                3.50
#
# Element_Name       Written Comprehension_Importance  \
# Title
# Accountants                                    4.00
# Actors                                         3.88
# Actuaries                                      4.00
# Acupuncturists                                 3.50
# Acute Care Nurses                              4.00
#
# Element_Name       Written Expression_Importance
# Title
# Accountants                                 3.75
# Actors                                      2.88
# Actuaries                                   3.75
# Acupuncturists                              3.25
# Acute Care Nurses                           3.75
#
# [5 rows x 523 columns]
